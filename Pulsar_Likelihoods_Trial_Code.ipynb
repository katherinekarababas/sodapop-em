# %% [markdown]
# <a href="https://colab.research.google.com/github/katherinekarababas/sodapop-em/blob/master/Pulsar_Likelihoods_Trial_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# download and install the code

# %%bash
# make this cell an instance of a terminal

git clone https://github.com/katherinekarababas/sodapop-em.git #download code repository from my GitHub account 

mkdir /opt/bin /opt/lib/ /opt/lib/python3.7 /opt/lib/python3.7/site-packages #create install directory and make it findable
export PATH=$PATH:/opt/bin
export PYTHONPATH=$PYTHONPATH:/opt/lib/python3.7/site-packages

cd sodapop-em #install code
# git pull 
python3 setup.py install --prefix /opt/

python3 -m pip install emcee #install emcee package to handle markov-chain monte carlo sampling

echo -e '\n *** \n'

sample-pop-params -h #executable that draws samples in the population model's parameters

echo -e '\n *** \n'

infer-pop-params-em -h #executable that calculates the posterior probability of the sampled population parameters

echo -e '\n *** \n'

build-ppd -h #executable that postprocesses the population posterior samples to calculate the inferred mass distribution

echo -e '\n *** \n'
# Out:
# running install
# running bdist_egg
# running egg_info
# creating sodapop.egg-info
# writing sodapop.egg-info/PKG-INFO
# writing dependency_links to sodapop.egg-info/dependency_links.txt
# writing top-level names to sodapop.egg-info/top_level.txt
# writing manifest file 'sodapop.egg-info/SOURCES.txt'
# writing manifest file 'sodapop.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/sodapop
# copying sodapop/select.py -> build/lib/sodapop
# copying sodapop/emcee.py -> build/lib/sodapop
# copying sodapop/parameters.py -> build/lib/sodapop
# copying sodapop/diagnostics.py -> build/lib/sodapop
# copying sodapop/populations.py -> build/lib/sodapop
# copying sodapop/__init__.py -> build/lib/sodapop
# copying sodapop/priors.py -> build/lib/sodapop
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/select.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/emcee.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/parameters.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/diagnostics.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/populations.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/__init__.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/priors.py -> build/bdist.linux-x86_64/egg/sodapop
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/select.py to select.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/emcee.py to emcee.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/parameters.py to parameters.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/diagnostics.py to diagnostics.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/populations.py to populations.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/priors.py to priors.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# installing scripts to build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# running install_scripts
# running build_scripts
# creating build/scripts-3.7
# copying bin/sample-pop-params.sh -> build/scripts-3.7
# copying and adjusting bin/reweight-masses -> build/scripts-3.7
# copying and adjusting bin/build-ppd -> build/scripts-3.7
# copying and adjusting bin/extract-pop-param-quantiles -> build/scripts-3.7
# copying and adjusting bin/build-ppd-em -> build/scripts-3.7
# copying and adjusting bin/infer-pop-params-em -> build/scripts-3.7
# copying and adjusting bin/infer-pop-params -> build/scripts-3.7
# copying bin/write-execs -> build/scripts-3.7
# copying and adjusting bin/POP-FIT-CONDOR -> build/scripts-3.7
# copying bin/infer-pop-params.sh -> build/scripts-3.7
# copying and adjusting bin/checkpopmodels -> build/scripts-3.7
# copying and adjusting bin/sample-pop-params -> build/scripts-3.7
# copying and adjusting bin/plot-pop-model -> build/scripts-3.7
# changing mode of build/scripts-3.7/reweight-masses from 644 to 755
# changing mode of build/scripts-3.7/build-ppd from 644 to 755
# changing mode of build/scripts-3.7/extract-pop-param-quantiles from 644 to 755
# changing mode of build/scripts-3.7/build-ppd-em from 644 to 755
# changing mode of build/scripts-3.7/infer-pop-params-em from 644 to 755
# changing mode of build/scripts-3.7/infer-pop-params from 644 to 755
# changing mode of build/scripts-3.7/write-execs from 644 to 755
# changing mode of build/scripts-3.7/POP-FIT-CONDOR from 644 to 755
# changing mode of build/scripts-3.7/checkpopmodels from 644 to 755
# changing mode of build/scripts-3.7/sample-pop-params from 644 to 755
# changing mode of build/scripts-3.7/plot-pop-model from 644 to 755
# creating build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/sample-pop-params.sh -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/reweight-masses -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/build-ppd -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/extract-pop-param-quantiles -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/build-ppd-em -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/infer-pop-params-em -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/infer-pop-params -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/write-execs -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/POP-FIT-CONDOR -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/infer-pop-params.sh -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/checkpopmodels -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/sample-pop-params -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/plot-pop-model -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/sample-pop-params.sh to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/reweight-masses to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/build-ppd to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/extract-pop-param-quantiles to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/build-ppd-em to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/infer-pop-params-em to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/infer-pop-params to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/write-execs to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/POP-FIT-CONDOR to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/infer-pop-params.sh to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/checkpopmodels to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/sample-pop-params to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/plot-pop-model to 755
# copying sodapop.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sodapop.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sodapop.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sodapop.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/sodapop-0.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing sodapop-0.0-py3.7.egg
# Copying sodapop-0.0-py3.7.egg to /opt/lib/python3.7/site-packages
# Adding sodapop 0.0 to easy-install.pth file
# Installing POP-FIT-CONDOR script to /opt//bin
# Installing build-ppd script to /opt//bin
# Installing build-ppd-em script to /opt//bin
# Installing checkpopmodels script to /opt//bin
# Installing extract-pop-param-quantiles script to /opt//bin
# Installing infer-pop-params script to /opt//bin
# Installing infer-pop-params-em script to /opt//bin
# Installing infer-pop-params.sh script to /opt//bin
# Installing plot-pop-model script to /opt//bin
# Installing reweight-masses script to /opt//bin
# Installing sample-pop-params script to /opt//bin
# Installing sample-pop-params.sh script to /opt//bin
# Installing write-execs script to /opt//bin
#
# Installed /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg
# Processing dependencies for sodapop==0.0
# Finished processing dependencies for sodapop==0.0
# Collecting emcee
#   Downloading emcee-3.1.1-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from emcee) (1.19.5)
# Installing collected packages: emcee
# Successfully installed emcee-3.1.1
#
#  ***
#
# usage: sample-pop-params [-h] [-d DELIM] [-n NUMSAMPS]
#                          [-p PRIORS [PRIORS ...]] [-F FIXED [FIXED ...]]
#                          [-o OUTPATH] [-g GRIDPTS] [-v]
#                          popmodel
#
# SAMPLE-POP-PARAMS -- sample population model parameters
#
# positional arguments:
#   popmodel
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -d DELIM, --delim DELIM
#                         delimiter for data file, DEFAULT=","
#   -n NUMSAMPS, --numsamps NUMSAMPS
#                         number of samples to draw, DEFAULT=1000
#   -p PRIORS [PRIORS ...], --priors PRIORS [PRIORS ...]
#                         prior distribution and hyperparameters for each
#                         population parameter, DEFAULT="mmax+flat,0.,1."
#   -F FIXED [FIXED ...], --fixed FIXED [FIXED ...]
#                         fixed population parameter values (e.g. mmin,1.0),
#                         DEFAULT=False
#   -o OUTPATH, --outpath OUTPATH
#                         path for output reweighted samples, DEFAULT=AUTO
#   -g GRIDPTS, --gridpts GRIDPTS
#                         number of grid points to build prior on, DEFAULT=10000
#   -v, --verbose
#
#  ***
#
# usage: infer-pop-params-em [-h] [-C CLAS [CLAS ...]] [-c COL [COL ...]]
#                            [-l NLIKE] [-p POPMOD] [-P PRIORS [PRIORS ...]]
#                            [-F FIXED [FIXED ...]] [-D DISTPRIOR]
#                            [-B BHPOP [BHPOP ...]] [-f SELFUNC] [-S SELPRIORS]
#                            [-s NSEL] [-t NPOST] [-w NWALK] [-b NBURN]
#                            [-o OUTPATH] [-d DELIM] [--batch BATCH] [--diag]
#                            [-v]
#                            popparams likedata [likedata ...]
#
# INFER-POP-PARAMS -- infer population parameters based on population model and
# observations
#
# positional arguments:
#   popparams
#   likedata
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -C CLAS [CLAS ...], --clas CLAS [CLAS ...]
#                         psr classification of each event, DEFAULT="psr ..."
#   -c COL [COL ...], --col COL [COL ...]
#                         name of pulsar mass, DEFAULT="pulsar_mass"
#   -l NLIKE, --nlike NLIKE
#                         number of likelihood samples to use, DEFAULT=1e3
#   -p POPMOD, --popmod POPMOD
#                         name of pulsar population model, DEFAULT="unif_mass"
#   -P PRIORS [PRIORS ...], --priors PRIORS [PRIORS ...]
#                         prior distribution and hyperparameters for each
#                         population parameter,
#                         DEFAULT="mmin,mmax+flat12,1.,1.5,1.5,3."
#   -F FIXED [FIXED ...], --fixed FIXED [FIXED ...]
#                         fixed population parameter values (e.g. mmin,1.0),
#                         DEFAULT=False
#   -D DISTPRIOR, --distprior DISTPRIOR
#                         prior distribution for the distance,
#                         DEFAULT="quad,0.,1000."
#   -B BHPOP [BHPOP ...], --bhpop BHPOP [BHPOP ...]
#                         population parameters for fixed BH mass model (e.g.
#                         mmin mmax beta), DEFAULT=3. 60. 2.
#   -f SELFUNC, --selfunc SELFUNC
#                         name of selection function, DEFAULT=False
#   -S SELPRIORS, --selpriors SELPRIORS
#                         ranges in m1,m2 and dL for integrating selection
#                         function, DEFAULT="1.,60.,1.,3.,0.,1000."
#   -s NSEL, --nsel NSEL  number of samples to use for integrating selection
#                         function, DEFAULT=10000
#   -t NPOST, --npost NPOST
#                         target number of posterior samples, DEFAULT=10000
#   -w NWALK, --nwalk NWALK
#                         number of MCMC chains, DEFAULT=15
#   -b NBURN, --nburn NBURN
#                         number of burn-in samples, DEFAULT=1000
#   -o OUTPATH, --outpath OUTPATH
#                         path for output population parameter samples,
#                         DEFAULT=AUTO
#   -d DELIM, --delim DELIM
#                         delimiter for data file, DEFAULT=","
#   --batch BATCH         start line of population parameters file for batch
#                         mode operation, DEFAULT=False
#   --diag                produce diagnostic plots, DEFAULT=False
#   -v, --verbose
#
#  ***
#
# usage: build-ppd [-h] [-p POPMOD] [-s NSEL] [-m MAXSAMPS] [-f SELFUNC]
#                  [-o OUTPATH] [-d DELIM] [-t TYPE] [-v]
#                  popparams
#
# BUILD-PPD -- build posterior predictive distribution from posterior population
# distribution
#
# positional arguments:
#   popparams
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -p POPMOD, --popmod POPMOD
#                         name of population model, DEFAULT="unif_m1m2"
#   -s NSEL, --nsel NSEL  number of samples to use for integrating ppd,
#                         DEFAULT=5000
#   -m MAXSAMPS, --maxsamps MAXSAMPS
#                         maximum number of population samples to use in
#                         marginalization, DEFAULT=10000
#   -f SELFUNC, --selfunc SELFUNC
#                         name of selection function, DEFAULT=False
#   -o OUTPATH, --outpath OUTPATH
#                         path for output ppd file, DEFAULT=AUTO
#   -d DELIM, --delim DELIM
#                         delimiter for data file, DEFAULT=","
#   -t TYPE, --type TYPE  type of ppd to plot, DEFAULT=mean
#   -v, --verbose
#
#  ***
# Cloning into 'sodapop-em'...
# zip_safe flag not set; analyzing archive contents...

# %%
# hopefully faster to run changed in packages
# %%bash

export PATH=$PATH:/opt/bin
export PYTHONPATH=$PYTHONPATH:/opt/lib/python3.7/site-packages

cd sodapop-em #install code
git pull 
python3 setup.py install --prefix /opt/
# Out:
# Updating a1dfaef..5013fd0
# Fast-forward
#  sodapop/emcee.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)
# running install
# running bdist_egg
# running egg_info
# writing sodapop.egg-info/PKG-INFO
# writing dependency_links to sodapop.egg-info/dependency_links.txt
# writing top-level names to sodapop.egg-info/top_level.txt
# writing manifest file 'sodapop.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying sodapop/emcee.py -> build/lib/sodapop
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/__init__.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/diagnostics.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/select.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/populations.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/priors.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/parameters.py -> build/bdist.linux-x86_64/egg/sodapop
# copying build/lib/sodapop/emcee.py -> build/bdist.linux-x86_64/egg/sodapop
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/diagnostics.py to diagnostics.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/select.py to select.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/populations.py to populations.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/priors.py to priors.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/parameters.py to parameters.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/sodapop/emcee.py to emcee.cpython-37.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# installing scripts to build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# running install_scripts
# running build_scripts
# creating build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/sample-pop-params -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/reweight-masses -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/plot-pop-model -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/infer-pop-params.sh -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/write-execs -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/POP-FIT-CONDOR -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/build-ppd -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/checkpopmodels -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/extract-pop-param-quantiles -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/infer-pop-params-em -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/infer-pop-params -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# copying build/scripts-3.7/sample-pop-params.sh -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/sample-pop-params to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/reweight-masses to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/plot-pop-model to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/infer-pop-params.sh to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/write-execs to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/POP-FIT-CONDOR to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/build-ppd to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/checkpopmodels to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/extract-pop-param-quantiles to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/infer-pop-params-em to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/infer-pop-params to 755
# changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/sample-pop-params.sh to 755
# copying sodapop.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sodapop.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sodapop.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying sodapop.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/sodapop-0.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing sodapop-0.0-py3.7.egg
# Removing /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg
# Copying sodapop-0.0-py3.7.egg to /opt/lib/python3.7/site-packages
# sodapop 0.0 is already the active version in easy-install.pth
# Installing POP-FIT-CONDOR script to /opt//bin
# Installing build-ppd script to /opt//bin
# Installing checkpopmodels script to /opt//bin
# Installing extract-pop-param-quantiles script to /opt//bin
# Installing infer-pop-params script to /opt//bin
# Installing infer-pop-params-em script to /opt//bin
# Installing infer-pop-params.sh script to /opt//bin
# Installing plot-pop-model script to /opt//bin
# Installing reweight-masses script to /opt//bin
# Installing sample-pop-params script to /opt//bin
# Installing sample-pop-params.sh script to /opt//bin
# Installing write-execs script to /opt//bin
#
# Installed /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg
# Processing dependencies for sodapop==0.0
# Finished processing dependencies for sodapop==0.0
# From https://github.com/katherinekarababas/sodapop-em
#    a1dfaef..5013fd0  master     -> origin/master
# zip_safe flag not set; analyzing archive contents...

# %%
#function to create Gaussuian likelihoods for pulsar mass measurements

import numpy as np
psr_mass = np.array([1.96, 1.71, 1.21, 1.57, 1.53, 1.96, 1.74, 2.0, 2.12, 1.02, 1.57, 1.073, 1.44, 1.91, 1.57, 1.41, 1.559, 1.174, 1.291, 1.322, 1.3332, 1.3452, 1.4398, 1.3886, 1.358, 1.354, 1.3381, 1.2489, 1.312, 1.258, 1.3655, 1.2064, 1.33, 1.40, 1.35, 1.37, 1.72, 1.27, 1.47, 1.908, 2.01, 1.76, 1.393, 1.47, 1.83, 1.44, 1.48, 1.24, 1.34, 1.38, 1.4378, 1.828, 1.29, 2.3, 1.58, 1.71, 1.666, 2.08])
psr_sd = np.array([0.19, 0.21, 0.12, 0.16, 0.42, 0.36, 0.3, 0.4, 0.16, 0.17, 0.11, 0.36, 0.1, 0.45, 0.25, 0.24, 0.004, 0.004, 0.011, 0.011, 0.0010, 0.0010, 0.0002, 0.0002, 0.010, 0.010, 0.0007, 0.0007, 0.017, 0.017, 0.0021, 0.0020, 0.3, 0.21, 0.07, 0.13, 0.07, 0.01, 0.07, 0.016, 0.04, 0.06, 0.013, 0.43, 0.11, 0.07, 0.03, 0.11, 0.08, 0.13, 0.0013, 0.022, 0.1, 0.7, 0.34, 0.16, 0.01, 0.07])
psr_name = ['4U1700-377', 'Cyg_X-2', 'SMC_X-1', 'Cen_X-3', 'XTE_J2123-058', '4U_1822-37', 'OAO_1657-415', 'J013236.7+303228', 'Vela_X-1', '4U1538-522', 'LMC_X-4', 'Her_X-1', '2S_0921-630', 'EXO_1722-363', 'SAXJ1802.7-2017', 'XTEJ1855-026', 'J0453+1559', 'J0453+1559_comp.', 'J1906+0746', 'J190+0746_comp.', 'B1534+12', 'B1534+12_comp.', 'B1913+16', 'B1913+16_comp.', 'B2127+11C', 'B2127+11C_comp.', 'J0737-3039A', 'J0737-3039B', 'J1756-2251', 'J1756-2251_comp.', 'J1807-2500B', 'J1807-2500B_comp.', 'J2045+3633', 'J2053+4650', 'J1713+0747', 'B1855+09', 'J0751+1807', 'J1141-6545', 'J1738+0333', 'J1614-2230', 'J0348+0432', 'J2222-0137', 'J2234+0611', 'J1949+3106', 'J1012+5307', 'J0437+4715', 'J1909-3744', 'J1802-2124', 'J1911-5958A', 'J2043+1711', 'J0337+1715', 'J1946+3417', 'J1918-0642', 'J1600-3053', 'J0045-7319', 'J1023+0038', 'J1903+0327', 'J0740+6602']

wts = np.ones(100) #need to include this as equal likelihoods for each sample

for i in range(0,58):
  mu, sigma = psr_mass[i], psr_sd[i] # psr mass and sd respectively
  s = np.random.normal(mu, sigma, 100) # likelihood samples 
  np.savetxt('psr_'+psr_name[i]+'.csv', np.column_stack([s,wts]), delimiter=',', header='m,likelihood', comments ='')

# %%
# function to create likelihoods for mass function and total mass with test values (test values to understand what's going on)
m_func = 0.13
m_mean = 2.5
mt_un = 0.01


def likelihood_tm(m_total, m_psr, m_func, m_mean, mt_un): # equation 4 from A Population-Informed Mass Estimate for Pulsar J0740+6620 paper
    return np.exp(-(m_total-m_mean)**2/(2*mt_un**2))*m_total**(4/3)/(3*(m_total-m_psr)**2*m_func**(1/3)*(1-(m_func**(2/3)*m_total**(4/3))/(m_total-m_psr)**2)**(1/2))

mt_samples = np.random.normal(m_mean, mt_un, 100) # likelihood samples for the total mass 
psr_samples = np.random.uniform(1.4, 1.4, 100) # likelihood samples for the pulsar mass (inital values were 1.4 and 1.4)

tm_like = []
for i,j in zip(mt_samples, psr_samples):
  tm_like += [likelihood_tm(i, j, m_func, m_mean, mt_un)]

print ('tm_like =', tm_like) #probabilities of pulsar masses given the defined values

samples = np.random.choice(range(100), 10, True, tm_like/np.sum(tm_like)) # likelihood samples
print ('samples =', samples) # pretty sure these give random points to match the total mass with the pulsar mass likelihoods together

for index in samples:
  print (mt_samples[index], psr_samples[index])
# Out:
# tm_like = [3.445077916842117, 0.6073438028536899, 2.251278572968885, 3.133505640636651, 1.1240261865364227, 0.19618692231407134, 1.4617746554030753, 0.3853672555701727, 2.2776087700512386, 0.5826325967402564, 3.437505072673602, 0.1792475567104339, 1.5866545102628655, 3.07165992096383, 2.3774690973129413, 3.4843760384569884, 1.3363271898496685, 0.41921392134388724, 3.4692182417523654, 2.946969691302855, 2.2146081883699806, 3.4859901659407018, 3.319568686588858, 2.9891370059459024, 2.486919352284569, 2.5729211962101353, 3.253545766038985, 3.260021269607204, 1.4546137377816026, 0.22385518754944791, 3.40064882952249, 3.30571540290582, 3.4451623393857256, 3.466785685334703, 2.5700688045039084, 3.4313701537093007, 2.992891572298433, 0.7242408691810592, 3.2344060762501994, 3.181650332514064, 2.8460534878087436, 2.9947028723966667, 2.290972040428879, 3.4212209982824144, 2.9853546578504417, 2.4761246964596144, 1.8017233255529217, 1.47397151463914, 3.2163441831570605, 1.1135688560586334, 0.2228474923998653, 2.9887033179206948, 2.1080316758293485, 3.1218338256798854, 0.4913736807603855, 3.0529605056887563, 0.17390789850888833, 2.9500998584061944, 2.1843514621616134, 0.7861797749333969, 2.5914553032397163, 1.4329277680400607, 3.461897926528955, 3.4805668833497183, 1.6313040491525375, 0.6455715725139702, 3.3947298045216034, 3.0882585731114998, 3.4066305512146853, 3.4415753126910893, 3.458925104381602, 2.342355587114765, 0.7807722949853069, 0.828393081973934, 0.24339226054505977, 3.484356473068414, 1.4401099921624414, 2.9835789597833497, 3.1715571724022036, 2.7651653081036227, 2.2305108706236383, 3.024876450505397, 3.439538787724735, 2.5836418004803585, 0.462927305904626, 1.5125704960284867, 1.4131404091833148, 1.9381497676871902, 3.27459466894869, 3.423195509411486, 3.1350394837652815, 2.734264605941374, 0.3120483161233495, 2.12663865139708, 2.2260534567538395, 2.890480542206723, 1.1519575939701368, 3.3456808854581346, 3.244385468569842, 0.44128353229028416]
# samples = [91 48 23 75  0 59 66 21 79 27]
# 2.49273228666109 1.4
# 2.5037217899951614 1.4
# 2.4941571958108666 1.4
# 2.5000212304913685 1.4
# 2.4981671602299693 1.4
# 2.482437547911834 1.4
# 2.497400520459162 1.4
# 2.4996334171418497 1.4
# 2.4928955166732263 1.4
# 2.4960424798253786 1.4

# %%
#function to create likelihoods for mass function and total mass with all of these pulsars (this is the official cell with the .csv file at the end)

m_func = np.array ([0.136344, 0.001927, 0.14549547, 0.027026849, 0.000646723, 0.0002266235, 0.003658, 0.013066, 0.00945034, 0.006553, 0.246261924525, 0.0518649]) # mass funtion
m_mean = np.array ([2.875, 1.665, 2.453, 2.32, 2.29, 2.92, 2.17, 2.20, 1.62, 1.616, 2.64, 1.97]) # total mass
mt_un = np.array ([0.014, 0.007, 0.014, 0.08, 0.17, 0.20, 0.02, 0.04, 0.07, 0.007, 0.05, 0.15]) # uncertainty for each total mass
psr_mt_name = ['J1913+1102', 'J0024-7204H', 'J0514-4002A', 'J0621+1002', 'B1516+02B', 'J1748-2021B', 'J1748-2446I', 'J1748-2446J', 'B1802-07', 'J1824-2452C', 'B2303+46', 'J1750-37A'] #plusar name

# function is already done

# for loop to generate .csv files of the likelihood for each pulsar
for k in range(0,12):
  mt_samples = []
  psr_samples = []
  tm_like = []
  mt_samp =  np.array (np.random.normal(m_mean[k], mt_un[k], 100)) # likelihood samples for the total mass
  for i in mt_samp:
    psr_samp = np.random.uniform(1., i-m_func[k]**(1/3)*i**(2/3), 1)[0] # likelihood samples for the pulsar mass (upper limit ensures that pulsar mass is not greater than total mass)
    tm_like += [likelihood_tm(i, psr_samp, m_func[k], m_mean[k], mt_un[k])] # probabilities of pulsar masses given the defined values
    psr_samples = np.append(psr_samples, psr_samp)
    mt_samples = np.append(mt_samples, i)
  samples = np.random.choice(range(len(mt_samples)), 100, True, tm_like/np.sum(tm_like)) # likelihood samples 
  # print ('samples =', samples)
  # print ('tm_like =', tm_like)
  wts = np.ones((100,1)) #weight of each pulsar
  total_likes = []
  for index in samples:
    test = [mt_samples[index], psr_samples[index]]
    total_likes = np.append (total_likes, test)
  like_t = np.reshape(total_likes, (100,2)) # this is a 2D array of the total masses and the pulsar masses 
  np.savetxt('psr_mt_'+psr_mt_name[k]+'.csv', np.column_stack([like_t,wts]), delimiter=',', header='tm, m, likelihood', comments ='') # final .csv file

# %%
# function to create likelihoods for mass function and mass ratio (this cell was done with the first data point from the Alsing paper)

def likelihood_mr(m_ratio, m_psr, m_func, mr_mean, mr_un): # equation 5 from A Population-Informed Mass Estimate for Pulsar J0740+6620 paper
  return np.exp(-(m_ratio-mr_mean)**2/(2*mr_un**2)*(1+m_ratio)**(4/3)/(3*m_func**(1/3)*m_psr**(2/3)*m_ratio**2*(1-(m_func/m_psr)**(2/3)*(1/m_ratio)**(4/3)/m_ratio**2)))

# define the variables, though this is only one data point so far
m_func = 5e-6
mr_mean = 69.2
mr_un = 0.8

mr_samples = np.random.normal (mr_mean, mr_un, 100) # likelihood samples for the mass ratio
psr_samples = np.random.uniform (1., 3., 100) # lilkelihood samples for the pulsar mass 
#(tested from 1 to 3 solar masses; if error pops up with the other values, find the upper bound as with the total mass data in the cell above)

rm_like = [] # this will give the probabilities of pulsar masses given the defined values
for i,j in zip(mr_samples, psr_samples):
  rm_like += [likelihood_mr(i, j, m_func, mr_mean, mr_un)]

samples = np.random.choice (range(100), 10, True, rm_like/np.sum(rm_like)) # generate random points to sample from given the mass ratio porbabilities calculated above

for index in samples:
  print (mr_samples[index], psr_samples[index]) # this gives the mass ratio and pulsar mass vaules from the samples points chosen
# Out:
# 68.80835586214413 1.3661703246197183
# 69.7463013119408 2.5997306562007867
# 68.21226279962148 2.823383338070722
# 70.77460020125909 2.167559170078926
# 69.8191693178141 2.1051343590150644
# 69.76607266720183 1.9526201630495879
# 69.32787336425153 1.5111516466995432
# 68.93598113489621 1.2434619131614264
# 68.69983705789376 2.4309196710736214
# 68.69983705789376 2.4309196710736214

# %%
#function to create likelihoods for mass function and mass ratio with all of these pulsars (this is the official cell with the .csv file at the end)

#definition created in the cell above (likelihood_mr)

#all data points from Alsing paper
mr_func = np.array ([5e-6, 3e-7, 0.002644, 0.0017607, 0.005221]) # mass function
mr_mean = np.array ([69.2, 175, 5.85, 9.54, 3.45]) # mass ratio (q)
mr_un = np.array ([0.8, 3, 0.13, 0.21, 0.02]) # uncertainties for the mass ratios
psr_mr_name = ['B1957+20', 'J1311-3430', 'J1740-5350', 'J1816+4510', 'J1723-2837'] # pulsar name

# for loop to generate .csv files for the likelihood of each pulsar
for k in range(0,5):
  mr_samples = []
  psr_samples = []
  rm_like = []
  mr_samp = np.random.normal (mr_mean[k], mr_un[k], 100) # likelihood samples for the mass ratio
  for i in mr_samp:
    psr_samp = np.random.uniform (1., 3., 1)[0] # likelihhod samples for the pulsar mass 
    rm_like += [likelihood_mr(i, psr_samp, mr_func[k], mr_mean[k], mr_un[k])] # probabilities of the pulsar mass given each defined value
    psr_samples = np.append(psr_samples, psr_samp)
    mr_samples = np.append (mr_samples, i)
  samples = np.random.choice(range(len(mr_samples)), 100, True, rm_like/np.sum(rm_like)) # likelihood samples
  wts = np.ones ((100,1)) # weight of each pulsar 
  total_likes = []
  for index in samples:
    test = [mr_samples[index], psr_samples[index]]
    total_likes = np.append (total_likes, test) 
  likes_q = np.reshape (total_likes, (100,2)) # this is a 2D array of the mass ratios and the pulsar masses
  np.savetxt ('psr_mr_'+psr_mr_name[k]+'.csv', np.column_stack([likes_q,wts]), delimiter=',', header='q, m, likelihood', comments='') # final .csv files

# %%
#population inference

# observations
PATH = './' 
g_likelihood = ','.join(['psr_'+psr_name[i]+'.csv' for i in range(0,58)]) # gaussian pulsars
mt_likelihood = ','.join(['psr_mt_'+psr_mt_name[i]+'.csv' for i in range(0,12)]) # total mass pulsars
mr_likelihood = ','.join(['psr_mr_'+psr_mr_name[i]+'.csv' for i in range(0,5)])
likelihood = g_likelihood + ',' + mt_likelihood + ',' + mr_likelihood # list of both types of likelihoods
print (likelihood)

dat_type = 'psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr,psr' 
# just added another 12 psr to test if this will work 
likelihood_num = 100 

# population model using the power law in masses where the convention is m1 >= m2
pop_mod = 'peakcut_mass' #don't need two masses anymore 
cb_mod = 'unif_m1_peakcut_m2_qpair' #this doesn't matter anymore; it has no effect on the data we just kept it to not mess with the population parameters and inference cells 
pop_param = 'mmin,mmax+flat12,1.,1.5,1.5,3. mu+flat,1.,3. sigma+flat,0.01,2.' 
mcmc_start = 'mmin,mmax+flat12,1.,1.2,1.8,2.4 mu+flat,1.,1.5 sigma+flat,0.2,0.7'

# selection effect (we don't know for pulsar data so we don't use this)
chirp_mass = 'False' #defult to no selection effect 
samp_num = 1000 #number of samples to use for monte carlo calculation of detection fraction

# mcmc algorithm
walks = 10 #number of walkers for mcmc
post_samp = 1000 #only start saving posterior samples after this number of steps
post_num = 10000 #number of posterior samples to aim for; added more so there are more dots on the corner plot

# postprocessing
pop_num = 1000 #how many population models to average when computing inferred mass distribution
# Out:
# psr_4U1700-377.csv,psr_Cyg_X-2.csv,psr_SMC_X-1.csv,psr_Cen_X-3.csv,psr_XTE_J2123-058.csv,psr_4U_1822-37.csv,psr_OAO_1657-415.csv,psr_J013236.7+303228.csv,psr_Vela_X-1.csv,psr_4U1538-522.csv,psr_LMC_X-4.csv,psr_Her_X-1.csv,psr_2S_0921-630.csv,psr_EXO_1722-363.csv,psr_SAXJ1802.7-2017.csv,psr_XTEJ1855-026.csv,psr_J0453+1559.csv,psr_J0453+1559_comp..csv,psr_J1906+0746.csv,psr_J190+0746_comp..csv,psr_B1534+12.csv,psr_B1534+12_comp..csv,psr_B1913+16.csv,psr_B1913+16_comp..csv,psr_B2127+11C.csv,psr_B2127+11C_comp..csv,psr_J0737-3039A.csv,psr_J0737-3039B.csv,psr_J1756-2251.csv,psr_J1756-2251_comp..csv,psr_J1807-2500B.csv,psr_J1807-2500B_comp..csv,psr_J2045+3633.csv,psr_J2053+4650.csv,psr_J1713+0747.csv,psr_B1855+09.csv,psr_J0751+1807.csv,psr_J1141-6545.csv,psr_J1738+0333.csv,psr_J1614-2230.csv,psr_J0348+0432.csv,psr_J2222-0137.csv,psr_J2234+0611.csv,psr_J1949+3106.csv,psr_J1012+5307.csv,psr_J0437+4715.csv,psr_J1909-3744.csv,psr_J1802-2124.csv,psr_J1911-5958A.csv,psr_J2043+1711.csv,psr_J0337+1715.csv,psr_J1946+3417.csv,psr_J1918-0642.csv,psr_J1600-3053.csv,psr_J0045-7319.csv,psr_J1023+0038.csv,psr_J1903+0327.csv,psr_J0740+6602.csv,psr_mt_J1913+1102.csv,psr_mt_J0024-7204H.csv,psr_mt_J0514-4002A.csv,psr_mt_J0621+1002.csv,psr_mt_B1516+02B.csv,psr_mt_J1748-2021B.csv,psr_mt_J1748-2446I.csv,psr_mt_J1748-2446J.csv,psr_mt_B1802-07.csv,psr_mt_J1824-2452C.csv,psr_mt_B2303+46.csv,psr_mt_J1750-37A.csv,psr_mr_B1957+20.csv,psr_mr_J1311-3430.csv,psr_mr_J1740-5350.csv,psr_mr_J1816+4510.csv,psr_mr_J1723-2837.csv

# %%
# draw population parameter samples from model

# %%bash -s "$pop_mod" "$walks" "$mcmc_start"
# this cell is a separate terminal instance; with the -s option we are passing the variables we defined above into the terminal as $1,$2,...

export PATH=$PATH:/opt/bin # the code doesn't need to be reinstalled in each terminal, but we do need to point to the install directory like this each time
export PYTHONPATH=$PYTHONPATH:/opt/lib/python3.7/site-packages

sample-pop-params $1 -n $2 -p $3 -o ${1}_prior.csv -v # call the executable that draws the starting samples for the mcmc algorithm
# sample-pop-params [population model] -n [number of mcmc walkers] -p [distribution to draw population parameters from] -o [path where population samples should be output]

# %%
# do the population inference based on the pulsar data

# %%bash -s "$likelihood" "$pop_mod" "$PATH" "$cb_mod" "$dat_type" "$likelihood_num" "$pop_param" "$chirp_mass" "$samp_num" "$post_num" "$walks" "$post_samp"

export PATH=$PATH:/opt/bin
export PYTHONPATH=$PYTHONPATH:/opt/lib/python3.7/site-packages

IFS=',' read -r -a likes <<< "$1" # some bash magic to turn the lists into arrays
IFS=',' read -r -a classes <<< "$5" 

echo "$2"
infer-pop-params-em ${2}_prior.csv $(for like in "${likes[@]}"; do echo -n "${3}/${like} "; done) -p $2 -C ${classes[@]} -c m -l $6 -P $7 -B 3. 60. 0. -f $8 -s $9 -t ${10} -w ${11} -b ${12} -o ${2}.csv --diag -v # call the executable that runs the mcmc algorithm
# infer-pop-params [prior samples] [likelihood1 likelihood2 ...] -p [bns_pop_model nsbh_pop_model] -C [psr  ...] -c [likelihood column names] -l [number of likelihood samples] -P [prior distribution] -B [fixed black hole population parameters] -f [selection function] -s [number of selection samples] -t [number of posterior samples] -w [number of walkers] -b [number of burn-in samples] -o [path where posterior samples should be output]
# Out:
# peakcut_mass
# walkers: 10, burn in: 1000, target posterior samples: 10000, likelihood samples: 100, selection effect samples: 1000
# Loading likelihood data...
# .//psr_4U1700-377.csv
# .//psr_Cyg_X-2.csv
# .//psr_SMC_X-1.csv
# .//psr_Cen_X-3.csv
# .//psr_XTE_J2123-058.csv
# .//psr_4U_1822-37.csv
# .//psr_OAO_1657-415.csv
# .//psr_J013236.7+303228.csv
# .//psr_Vela_X-1.csv
# .//psr_4U1538-522.csv
# .//psr_LMC_X-4.csv
# .//psr_Her_X-1.csv
# .//psr_2S_0921-630.csv
# .//psr_EXO_1722-363.csv
# .//psr_SAXJ1802.7-2017.csv
# .//psr_XTEJ1855-026.csv
# .//psr_J0453+1559.csv
# .//psr_J0453+1559_comp..csv
# .//psr_J1906+0746.csv
# .//psr_J190+0746_comp..csv
# .//psr_B1534+12.csv
# .//psr_B1534+12_comp..csv
# .//psr_B1913+16.csv
# .//psr_B1913+16_comp..csv
# .//psr_B2127+11C.csv
# .//psr_B2127+11C_comp..csv
# .//psr_J0737-3039A.csv
# .//psr_J0737-3039B.csv
# .//psr_J1756-2251.csv
# .//psr_J1756-2251_comp..csv
# .//psr_J1807-2500B.csv
# .//psr_J1807-2500B_comp..csv
# .//psr_J2045+3633.csv
# .//psr_J2053+4650.csv
# .//psr_J1713+0747.csv
# .//psr_B1855+09.csv
# .//psr_J0751+1807.csv
# .//psr_J1141-6545.csv
# .//psr_J1738+0333.csv
# .//psr_J1614-2230.csv
# .//psr_J0348+0432.csv
# .//psr_J2222-0137.csv
# .//psr_J2234+0611.csv
# .//psr_J1949+3106.csv
# .//psr_J1012+5307.csv
# .//psr_J0437+4715.csv
# .//psr_J1909-3744.csv
# .//psr_J1802-2124.csv
# .//psr_J1911-5958A.csv
# .//psr_J2043+1711.csv
# .//psr_J0337+1715.csv
# .//psr_J1946+3417.csv
# .//psr_J1918-0642.csv
# .//psr_J1600-3053.csv
# .//psr_J0045-7319.csv
# .//psr_J1023+0038.csv
# .//psr_J1903+0327.csv
# .//psr_J0740+6602.csv
# .//psr_mt_J1913+1102.csv
# .//psr_mt_J0024-7204H.csv
# .//psr_mt_J0514-4002A.csv
# .//psr_mt_J0621+1002.csv
# .//psr_mt_B1516+02B.csv
# .//psr_mt_J1748-2021B.csv
# .//psr_mt_J1748-2446I.csv
# .//psr_mt_J1748-2446J.csv
# .//psr_mt_B1802-07.csv
# .//psr_mt_J1824-2452C.csv
# .//psr_mt_B2303+46.csv
# .//psr_mt_J1750-37A.csv
# .//psr_mr_B1957+20.csv
# .//psr_mr_J1311-3430.csv
# .//psr_mr_J1740-5350.csv
# .//psr_mr_J1816+4510.csv
# .//psr_mr_J1723-2837.csv
# emcee ran for 424.3804054260254 seconds
# autocorrelation lengths for population parameters are [117.4731501  293.78005131 112.27597113 177.50785943]
# number of independent samples is 350
# effective samples per second is 0
# /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg/sodapop/emcee.py:34: RuntimeWarning: divide by zero encountered in log
# /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg/sodapop/emcee.py:15: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.7/dist-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg/sodapop/populations.py:97: RuntimeWarning: divide by zero encountered in true_divide
# /opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg/sodapop/populations.py:97: RuntimeWarning: invalid value encountered in true_divide
# The chain is shorter than 50 times the integrated autocorrelation time for 1 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 220;
# tau: [117.4731501  293.78005131 112.27597113 177.50785943]

# %%
# calculate the inferred mass distribution from the population posterior samples

# %%bash -s "$pop_mod" "$samp_num" "$chirp_mass" "$pop_num"

export PATH=$PATH:/opt/bin
export PYTHONPATH=$PYTHONPATH:/opt/lib/python3.7/site-packages

build-ppd ${1}.csv -p $1 -s $2 -f $3 -m $4 -o ${1}_ppd.csv -v # call the executable that draws the starting samples for the mcmc algorithm
# build-ppd [posterior samples] -p [population model] -s [number of selection effect samples] -f [selection function] -m [number of population models to average] -o [path where inferred mass distribution should be output]
# Out:
# Traceback (most recent call last):
#   File "/opt/bin/build-ppd", line 4, in <module>
#     __import__('pkg_resources').run_script('sodapop==0.0', 'build-ppd')
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 651, in run_script
#     self.require(requires)[0].run_script(script_name, ns)
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 1455, in run_script
#     exec(script_code, namespace, namespace)
#   File "/opt/lib/python3.7/site-packages/sodapop-0.0-py3.7.egg/EGG-INFO/scripts/build-ppd", line 97, in <module>
# TypeError: peakcut_mass() takes 2 positional arguments but 3 were given
